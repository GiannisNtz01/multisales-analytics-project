# %%
salesperson = spark.read.table("sales_lakehouse.silver.salesperson")

# %%
dim_salesperson = (
salesperson.select("employee_key", "employee_id", "salesperson_name", "title")
)

# %%
(dim_salesperson.write .mode("overwrite") .option("overwriteSchema", "true") .format("delta") .saveAsTable("sales_lakehouse.gold.dim_salesperson"))
